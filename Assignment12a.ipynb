# %%
# !conda install -c conda-forge textblob--yes
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - textblob--yes
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/osx-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
pip install --user -U nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
##Assignment12.ipynb
##CharlesWiredu
import nltk
nltk.download('punkt')
nltk.download('brown')
from textblob import TextBlob
def menu():
    print('Choose from the following options:')


while True:
    menu()
    user_input= print('1. Enter a new corpus of text.\n2. Print a report summarizing the total number of words and total number of sentences.\n3. Print a list of all the noun phrases, one per line.\n4. Print a sentiment analysis, listing the polarity and subjectivity of the corpus.\n5. Exit the program.')
    user_input= int(input('Enter your choice: '))
    
    ## if the user enter 5 break
    if user_input== 1:
        text=print(input('Enter a new corpus of text.\n'))
        print()
    elif user_input==2:
        Text=('''Biden and his running mate Kamala Harris defeated incumbent president Donald Trump and vice president 
        Mike Pence in the 2020 presidential election. He is the oldest president and the first to have a female vice president. 
        His early presidential activity centered around proposing, lobbying for, and signing into law the American Rescue Plan 
        Act of 2021 to help the United States recover from the COVID-19 pandemic and the ongoing recession, as well as a series
        of executive orders. Biden's orders addressed the pandemic and reversed several Trump administration policies, including 
        rejoining the Paris Agreement on climate change and accepting new applications for Deferred Action for Childhood Arrivals 
        (DACA) recipients, although a federal judge blocked the latter. He completed the withdrawal of U.S. troops from Afghanistan
        by September 2021. During the withdrawal, the Afghan government collapsed and the Taliban seized control. Biden proposed the 
        Build Back Better Plan, aspects of which were incorporated into the bipartisan Infrastructure Investment and Jobs Act, which
        Biden signed into law in November 2021. In response to the February 2022 Russian invasion of Ukraine, Biden led the imposition
        of international sanctions on Russia, authorizing over $1 billion in U.S. weapons shipments to Ukraine.
        ''')
        text_blob= TextBlob(Text)
        text_words= text_blob.words
        text_sentence= text_blob.sentences
        total_words= len(text_blob.words)
        total_sentences= len(text_blob.sentences)
        print("Print a report summarizing the total number of words and total number of sentences.")
        print('The total number of words is :', total_words )
        print('The total number of sentences is:', total_sentences)
        print()
    elif user_input==3:
        Text=('''Biden and his running mate Kamala Harris defeated incumbent president Donald Trump and vice president 
        Mike Pence in the 2020 presidential election. He is the oldest president and the first to have a female vice president. 
        His early presidential activity centered around proposing, lobbying for, and signing into law the American Rescue Plan 
        Act of 2021 to help the United States recover from the COVID-19 pandemic and the ongoing recession, as well as a series
        of executive orders. Biden's orders addressed the pandemic and reversed several Trump administration policies, including 
        rejoining the Paris Agreement on climate change and accepting new applications for Deferred Action for Childhood Arrivals 
        (DACA) recipients, although a federal judge blocked the latter. He completed the withdrawal of U.S. troops from Afghanistan
        by September 2021. During the withdrawal, the Afghan government collapsed and the Taliban seized control. Biden proposed the 
        Build Back Better Plan, aspects of which were incorporated into the bipartisan Infrastructure Investment and Jobs Act, which
        Biden signed into law in November 2021. In response to the February 2022 Russian invasion of Ukraine, Biden led the imposition
        of international sanctions on Russia, authorizing over $1 billion in U.S. weapons shipments to Ukraine.
        ''')
        print("Print a list of all the noun phrases, one per line.")
        text_blob= TextBlob(Text)
        nounphrase= text_blob.noun_phrases
        for line in nounphrase:
            print (line)
       
        print()
    elif user_input==4:
        Text=('''Biden and his running mate Kamala Harris defeated incumbent president Donald Trump and vice president 
        Mike Pence in the 2020 presidential election. He is the oldest president and the first to have a female vice president. 
        His early presidential activity centered around proposing, lobbying for, and signing into law the American Rescue Plan 
        Act of 2021 to help the United States recover from the COVID-19 pandemic and the ongoing recession, as well as a series
        of executive orders. Biden's orders addressed the pandemic and reversed several Trump administration policies, including 
        rejoining the Paris Agreement on climate change and accepting new applications for Deferred Action for Childhood Arrivals 
        (DACA) recipients, although a federal judge blocked the latter. He completed the withdrawal of U.S. troops from Afghanistan
        by September 2021. During the withdrawal, the Afghan government collapsed and the Taliban seized control. Biden proposed the 
        Build Back Better Plan, aspects of which were incorporated into the bipartisan Infrastructure Investment and Jobs Act, which
        Biden signed into law in November 2021. In response to the February 2022 Russian invasion of Ukraine, Biden led the imposition
        of international sanctions on Russia, authorizing over $1 billion in U.S. weapons shipments to Ukraine.
        ''')
        print("Print a list of all the noun phrases, one per line.")
        text_blob= TextBlob(Text)
        sentiment_polarity= text_blob.sentiment.polarity
        sentiment_subjectivity= text_blob.sentiment.subjectivity
        print("Print a sentiment analysis, listing the polarity and subjectivity of the corpus.")
        print('The overall sentiment polarity of this selection (-1.0 is negative, 0.0 is neutral, and +1.0 is positive):\n', sentiment_polarity)
        print('The overal sentiment objectivity (0.0 is objective, 1.0 is subjective):\n',sentiment_subjectivity )
        print()
    elif user_input==5:
        print("Exit the program.")
        break
    else:
        print("invalid input")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/carlkwamesarfo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/carlkwamesarfo/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Choose from the following options:
# 1. Enter a new corpus of text.
# 2. Print a report summarizing the total number of words and total number of sentences.
# 3. Print a list of all the noun phrases, one per line.
# 4. Print a sentiment analysis, listing the polarity and subjectivity of the corpus.
# 5. Exit the program.
# Enter your choice: 1
# Enter a new corpus of text.
# ...
