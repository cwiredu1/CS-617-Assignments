# %%
##Assignment13.ipynb
##charleswiredu

##Importing required libraries
from textblob import TextBlob
import nltk
import requests
from bs4 import BeautifulSoup
from textatistic import Textatistic
###first website####
website1 = ' https://www.cnbc.com/2022/04/13/trump-white-house-aide-mark-meadows-removed-from-north-carolina-vote-rolls.html'  # save website address
response1 = requests.get(website1) # get http response through the internet
soup1 = BeautifulSoup(response1.content, 'html.parser') # process http response
text1 = soup1.get_text(strip=True) # remove html tags
#print(text1)
readability1 = Textatistic(text1)
print('Text from https://www.cnbc.com/2022/04/13/trump-white-house-aide-mark-meadows-removed-from-north-carolina-vote-rolls.html has results:')

print('Reability Dale-Chall score:',round(readability1.dalechall_score, 2), 'grade')


def sentence(text):
    sentence_1 = text.sentiment.polarity
    sentence_11 = text.sentiment.subjectivity
    if sentence_1 >= 0.6:
        print("Sentiment Polarity:",round(sentence_1,2),'which is',f'{0x1F601:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_11,2), 'which is mostly objective')
    elif sentence_1 < 0.6 and sentence_1 > 0.35:
        print("Sentiment Polarity:",round(sentence_1,2),'which is',f'{0x1F642:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_11,2), 'which is mostly objective')
    elif sentence_1 > -0.35 and sentence_1 < 0.35 :
        print("Sentiment Polarity:",round(sentence_1,2),'which is',f'{0x1F610:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_11,2), 'which is mostly objective')
    elif sentence_1 > -0.6 and sentence_1 < -0.35:
        print("Sentiment Polarity:",round(sentence_1,2),'which is',f'{0x1F615:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_11,2), 'which is mostly objective')
    elif sentence_1 <= -0.6:
        print("Sentiment Polarity:",round(sentence_1,2),'which is',f'{0x1F62D:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_11,2), 'which is mostly objective')
    else:
        print('Invalid Range')
user_text= text1
#print(user_text)
text_blob= TextBlob(user_text)
sentence(text_blob)

print()
####website2######
website2 = 'https://www.cbsnews.com/news/ketanji-brown-jackson-supreme-court-senate-confirmation-first-black-woman/'  # save website address
response2 = requests.get(website2) # get http response through the internet
soup2 = BeautifulSoup(response2.content, 'html.parser') # process http response
text2 = soup2.get_text(strip=True) # remove html tags
#print(text2)
readability2 = Textatistic(text2)
print('Text from https://www.cbsnews.com/news/ketanji-brown-jackson-supreme-court-senate-confirmation-first-black-woman/ has results:')

print('Reability Dale-Chall score:',round(readability2.dalechall_score, 2), 'grade')

def sentence1(text1):
    sentence_0 = text1.sentiment.polarity
    sentence_2 = text1.sentiment.subjectivity
    if sentence_0 >= 0.6:
        print("Sentiment Polarity:",round(sentence_0,2),'which is',f'{0x1F601:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_2,2), 'which is mostly objective')
    elif sentence_0 < 0.6 and sentence_0 > 0.35:
        print("Sentiment Polarity:",round(sentence_0,2),'which is',f'{0x1F642:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_2,2), 'which is mostly objective')
    elif sentence_0 > -0.35 and sentence_0 < 0.35 :
        print("Sentiment Polarity:",round(sentence_0,2),'which is',f'{0x1F610:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_2,2), 'which is mostly objective')
    elif sentence_0 > -0.6 and sentence_0 < -0.35:
        print("Sentiment Polarity:",round(sentence_0,2),'which is',f'{0x1F615:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_2,2), 'which is mostly objective')
    elif sentence_1 <= -0.6:
        print("Sentiment Polarity:",round(sentence_0,2),'which is',f'{0x1F62D:c}', 'neutral')
        print('Sentiment Subjectivity:',round(sentence_2,2), 'which is mostly objective')
    else:
        print('Invalid Range')
user_text2= text2
#print(user_text)
text_blob1= TextBlob(user_text2)
sentence1(text_blob1)
# Out:
# Text from https://www.cnbc.com/2022/04/13/trump-white-house-aide-mark-meadows-removed-from-north-carolina-vote-rolls.html has results:
# Reability Dale-Chall score: 11.03 grade
# Sentiment Polarity: 0.01 which is 😐 neutral
# Sentiment Subjectivity: 0.32 which is mostly objective
#
# Text from https://www.cbsnews.com/news/ketanji-brown-jackson-supreme-court-senate-confirmation-first-black-woman/ has results:
# Reability Dale-Chall score: 10.32 grade
# Sentiment Polarity: 0.14 which is 😐 neutral
# Sentiment Subjectivity: 0.45 which is mostly objective
